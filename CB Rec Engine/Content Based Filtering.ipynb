# %% [markdown]
# ## Content Based Filtering

# %% [markdown]
# This lab relies on files created in the **Create Datasets** lab. Be sure to run the code in lab_Create_Datasets.ipynb lab before completing this lab.
#
# This notebook should be run in with a **python3** kernel.

# %% [markdown]
# This lab illustrates:
# 1. how to build feature columns for a model using tf.feature_column
# 2. how to create custom evaluation metrics and add them to Tensorboard
# 3. how to train a model and make predictions with the saved model

# %% [markdown]
# Tensorflow Hub should already be installed. You can check using pip freeze.

# %%
# %bash
pip freeze | grep tensor
# Out:
# tensorboard==1.8.0
# tensorflow==1.8.0
# tensorflow-hub==0.1.1

# %% [markdown]
# If tensorflow-hub is not already install, uncomment the cell below and execute the commands. After doing the pip install, click **"Reset Session"** on the notebook so that the Python environment picks up the new packages.

# %%
#%bash
#pip install tensorflow-hub

# %%
import os
import tensorflow as tf
import numpy as np
import tensorflow_hub as hub
import shutil
PROJECT = 'munn-sandbox' # REPLACE WITH YOUR PROJECT ID
BUCKET = 'munn-sandbox-bucket' # REPLACE WITH YOUR BUCKET NAME
REGION = 'us-central1' # REPLACE WITH YOUR BUCKET REGION e.g. us-central1

# do not change these
os.environ['PROJECT'] = PROJECT
os.environ['BUCKET'] = BUCKET
os.environ['REGION'] = REGION
os.environ['TFVERSION'] = '1.8'

# %%
# %bash
gcloud config set project $PROJECT
gcloud config set compute/region $REGION
# Out:
# Updated property [core/project].
# Updated property [compute/region].

# %% [markdown]
# ### Build the feature columns for the model.

# %% [markdown]
# To start, we'll load the list of categories, authors and article ids we created in the previous **Create Datasets** notebook.

# %%
categories_list = open("categories.txt").read().splitlines()
authors_list = open("authors.txt").read().splitlines()
content_ids_list = open("content_ids.txt").read().splitlines()
mean_months_since_epoch = 523

# %% [markdown]
# In the cell below we'll define the feature columns to use in our model. If necessary, remind yourself the [various feature columns](https://www.tensorflow.org/api_docs/python/tf/feature_column) to use.
# For the embedded_title_column feature column, use a Tensorflow Hub Module to create an embedding of the article title. Since the articles and titles are in German, you'll want to use a German language embedding module.
# Explore the text embedding Tensorflow Hub modules [available here](https://alpha.tfhub.dev/). Filter by setting the language to 'German'. The 50 dimensional embedding should be sufficient for our purposes.

# %%
embedded_title_column = hub.text_embedding_column(
    key="title", 
    module_spec="https://tfhub.dev/google/nnlm-de-dim50/1",
    trainable=False)

content_id_column = tf.feature_column.categorical_column_with_hash_bucket(
    key="content_id",
    hash_bucket_size= len(content_ids_list))
embedded_content_column = tf.feature_column.embedding_column(
    categorical_column=content_id_column,
    dimension=10)

author_column = tf.feature_column.categorical_column_with_hash_bucket(
    key="author",
    hash_bucket_size=len(authors_list) + 1)
embedded_author_column = tf.feature_column.embedding_column(
    categorical_column=author_column,
    dimension=3)

category_column_categorical = tf.feature_column.categorical_column_with_vocabulary_list(
    key="category",
    vocabulary_list=categories_list,
    num_oov_buckets=1)
category_column = tf.feature_column.indicator_column(category_column_categorical)

months_since_epoch_boundaries = list(range(400,700,20))
months_since_epoch_column = tf.feature_column.numeric_column(
    key="months_since_epoch")
months_since_epoch_bucketized = tf.feature_column.bucketized_column(
    source_column = months_since_epoch_column,
    boundaries = months_since_epoch_boundaries)

crossed_months_since_category_column = tf.feature_column.indicator_column(tf.feature_column.crossed_column(
    [category_column_categorical, months_since_epoch_bucketized], len(months_since_epoch_boundaries) * (len(categories_list) + 1)))

feature_columns = [embedded_content_column,
                   embedded_author_column,
                   category_column,
                   embedded_title_column,
                   crossed_months_since_category_column]

# %% [markdown]
# ### Create the input function.
#
# Next we'll create the input function for our model. This input function reads the data from the csv files we created in the previous labs.

# %%
record_defaults = [["Unknown"], ["Unknown"],["Unknown"],["Unknown"],["Unknown"],[mean_months_since_epoch],["Unknown"]]
column_keys = ["visitor_id", "content_id", "category", "title", "author", "months_since_epoch", "next_content_id"]
label_key = "next_content_id"
def read_dataset(filename, mode, batch_size = 512):
  def _input_fn():
      #tf.tables_initializer()
      def decode_csv(value_column):
          columns = tf.decode_csv(value_column,record_defaults=record_defaults)
          features = dict(zip(column_keys, columns))          
          label = features.pop(label_key)         
          return features, label

      # Create list of files that match pattern
      file_list = tf.gfile.Glob(filename)

      # Create dataset from file list
      dataset = tf.data.TextLineDataset(file_list).map(decode_csv)

      if mode == tf.estimator.ModeKeys.TRAIN:
          num_epochs = None # indefinitely
          dataset = dataset.shuffle(buffer_size = 10 * batch_size)
      else:
          num_epochs = 1 # end-of-input after this

      dataset = dataset.repeat(num_epochs).batch(batch_size)
      return dataset.make_one_shot_iterator().get_next()
  return _input_fn

# %% [markdown]
# ### Create the model and train/evaluate
#
#
# Next, we'll build our model which recommends an article for a visitor to the Kurier.at website. Look through the code below. We use the input_layer feature column to create the dense input layer to our network. This is just a sigle layer network where we can adjust the number of hidden units as a parameter.
#
# Currently, we compute the accuracy between our predicted 'next article' and the actual 'next article' read next by the visitor. We'll also add an additional performance metric of top 10 accuracy to assess our model. To accomplish this, we compute the top 10 accuracy metric, add it to the metrics dictionary below and add it to the tf.summary so that this value is reported to Tensorboard as well.

# %%
def model_fn(features, labels, mode, params):
  net = tf.feature_column.input_layer(features, params['feature_columns'])
  for units in params['hidden_units']:
        net = tf.layers.dense(net, units=units, activation=tf.nn.relu)
   # Compute logits (1 per class).
  logits = tf.layers.dense(net, params['n_classes'], activation=None) 

  predicted_classes = tf.argmax(logits, 1)
  from tensorflow.python.lib.io import file_io
    
  with file_io.FileIO('content_ids.txt', mode='r') as ifp:
    content = tf.constant([x.rstrip() for x in ifp])
  predicted_class_names = tf.gather(content, predicted_classes)
  if mode == tf.estimator.ModeKeys.PREDICT:
    predictions = {
        'class_ids': predicted_classes[:, tf.newaxis],
        'class_names' : predicted_class_names[:, tf.newaxis],
        'probabilities': tf.nn.softmax(logits),
        'logits': logits,
    }
    return tf.estimator.EstimatorSpec(mode, predictions=predictions)
  table = tf.contrib.lookup.index_table_from_file(vocabulary_file="content_ids.txt")
  labels = table.lookup(labels)
  # Compute loss.
  loss = tf.losses.sparse_softmax_cross_entropy(labels=labels, logits=logits)

  # Compute evaluation metrics.
  accuracy = tf.metrics.accuracy(labels=labels,
                                 predictions=predicted_classes,
                                 name='acc_op')
  top_10_accuracy = tf.metrics.mean(tf.nn.in_top_k(predictions=logits, targets=labels, k=10))
  
  metrics = {
    'accuracy': accuracy,
    'top_10_accuracy' : top_10_accuracy}
  
  tf.summary.scalar('accuracy', accuracy[1])
  tf.summary.scalar('top_10_accuracy', top_10_accuracy[1])

  if mode == tf.estimator.ModeKeys.EVAL:
      return tf.estimator.EstimatorSpec(
          mode, loss=loss, eval_metric_ops=metrics)

  # Create training op.
  assert mode == tf.estimator.ModeKeys.TRAIN

  optimizer = tf.train.AdagradOptimizer(learning_rate=0.1)
  train_op = optimizer.minimize(loss, global_step=tf.train.get_global_step())
  return tf.estimator.EstimatorSpec(mode, loss=loss, train_op=train_op)

# %% [markdown]
# ### Train and Evaluate

# %%
outdir = 'content_based_model_trained'
shutil.rmtree(outdir, ignore_errors = True)
estimator = tf.estimator.Estimator(
    model_fn=model_fn,
    model_dir = outdir,
    params={
     'feature_columns': feature_columns,
      'hidden_units': [200, 100, 50],
      'n_classes': len(content_ids_list)
    })

train_spec = tf.estimator.TrainSpec(
    input_fn = read_dataset("training_set.csv", tf.estimator.ModeKeys.TRAIN),
    max_steps = 2000)

eval_spec = tf.estimator.EvalSpec(
    input_fn = read_dataset("test_set.csv", tf.estimator.ModeKeys.EVAL),
    steps = None,
    start_delay_secs = 30,
    throttle_secs = 60)

tf.estimator.train_and_evaluate(estimator, train_spec, eval_spec)
# Out:
# INFO:tensorflow:Using default config.
# INFO:tensorflow:Using config: {'_service': None, '_task_id': 0, '_log_step_count_steps': 100, '_tf_random_seed': None, '_num_worker_replicas': 1, '_keep_checkpoint_max': 5, '_train_distribute': None, '_master': '', '_num_ps_replicas': 0, '_save_summary_steps': 100, '_task_type': 'worker', '_save_checkpoints_secs': 600, '_keep_checkpoint_every_n_hours': 10000, '_session_config': None, '_is_chief': True, '_evaluation_master': '', '_global_id_in_cluster': 0, '_save_checkpoints_steps': None, '_model_dir': 'content_based_model_trained', '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f31f0291748>}
# INFO:tensorflow:Running training and evaluation locally (non-distributed).
# INFO:tensorflow:Start train and evaluate loop. The evaluate will happen after 60 secs (eval_spec.throttle_secs) or training is finished.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Initialize variable input_layer/title_hub_module_embedding/module/embeddings/part_0:0 from checkpoint b'/tmp/tfhub_modules/e40ef097142ae1de637df7021ce148ffe836e262/variables/variables' with embeddings
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 1 into content_based_model_trained/model.ckpt.
# INFO:tensorflow:loss = 9.657831, step = 1
# INFO:tensorflow:Saving checkpoints for 39 into content_based_model_trained/model.ckpt.
# INFO:tensorflow:Loss for final step: 7.8055506.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Initialize variable input_layer/title_hub_module_embedding/module/embeddings/part_0:0 from checkpoint b'/tmp/tfhub_modules/e40ef097142ae1de637df7021ce148ffe836e262/variables/variables' with embeddings
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-09-28-18:21:36
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from content_based_model_trained/model.ckpt-39
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-09-28-18:22:21
# INFO:tensorflow:Saving dict for global step 39: accuracy = 0.026641665, global_step = 39, loss = 7.4506636, top_10_accuracy = 0.21520372
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Initialize variable input_layer/title_hub_module_embedding/module/embeddings/part_0:0 from checkpoint b'/tmp/tfhub_modules/e40ef097142ae1de637df7021ce148ffe836e262/variables/variables' with embeddings
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from content_based_model_trained/model.ckpt-39
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 40 into content_based_model_trained/model.ckpt.
# INFO:tensorflow:loss = 7.4394255, step = 40
# INFO:tensorflow:Saving checkpoints for 80 into content_based_model_trained/model.ckpt.
# INFO:tensorflow:Loss for final step: 5.5335555.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Initialize variable input_layer/title_hub_module_embedding/module/embeddings/part_0:0 from checkpoint b'/tmp/tfhub_modules/e40ef097142ae1de637df7021ce148ffe836e262/variables/variables' with embeddings
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-09-28-18:23:33
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from content_based_model_trained/model.ckpt-80
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-09-28-18:24:18
# INFO:tensorflow:Saving dict for global step 80: accuracy = 0.02785265, global_step = 80, loss = 5.560167, top_10_accuracy = 0.17844447
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Initialize variable input_layer/title_hub_module_embedding/module/embeddings/part_0:0 from checkpoint b'/tmp/tfhub_modules/e40ef097142ae1de637df7021ce148ffe836e262/variables/variables' with embeddings
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from content_based_model_trained/model.ckpt-80
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 81 into content_based_model_trained/model.ckpt.
# INFO:tensorflow:loss = 5.5542946, step = 81
# INFO:tensorflow:Saving checkpoints for 122 into content_based_model_trained/model.ckpt.
# INFO:tensorflow:Loss for final step: 5.3809896.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Initialize variable input_layer/title_hub_module_embedding/module/embeddings/part_0:0 from checkpoint b'/tmp/tfhub_modules/e40ef097142ae1de637df7021ce148ffe836e262/variables/variables' with embeddings
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-09-28-18:25:27
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from content_based_model_trained/model.ckpt-122
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-09-28-18:26:11
# INFO:tensorflow:Saving dict for global step 122: accuracy = 0.026641665, global_step = 122, loss = 5.424227, top_10_accuracy = 0.17383492
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Initialize variable input_layer/title_hub_module_embedding/module/embeddings/part_0:0 from checkpoint b'/tmp/tfhub_modules/e40ef097142ae1de637df7021ce148ffe836e262/variables/variables' with embeddings
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from content_based_model_trained/model.ckpt-122
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 123 into content_based_model_trained/model.ckpt.
# INFO:tensorflow:loss = 5.322718, step = 123
# INFO:tensorflow:Saving checkpoints for 162 into content_based_model_trained/model.ckpt.
# INFO:tensorflow:Loss for final step: 5.346942.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Initialize variable input_layer/title_hub_module_embedding/module/embeddings/part_0:0 from checkpoint b'/tmp/tfhub_modules/e40ef097142ae1de637df7021ce148ffe836e262/variables/variables' with embeddings
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-09-28-18:27:22
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from content_based_model_trained/model.ckpt-162
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-09-28-18:28:09
# INFO:tensorflow:Saving dict for global step 162: accuracy = 0.032462206, global_step = 162, loss = 5.326092, top_10_accuracy = 0.22457908
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Initialize variable input_layer/title_hub_module_embedding/module/embeddings/part_0:0 from checkpoint b'/tmp/tfhub_modules/e40ef097142ae1de637df7021ce148ffe836e262/variables/variables' with embeddings
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from content_based_model_trained/model.ckpt-162
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 163 into content_based_model_trained/model.ckpt.
# INFO:tensorflow:loss = 5.290182, step = 163
# INFO:tensorflow:Saving checkpoints for 186 into content_based_model_trained/model.ckpt.
# INFO:tensorflow:Loss for final step: 5.277928.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Initialize variable input_layer/title_hub_module_embedding/module/embeddings/part_0:0 from checkpoint b'/tmp/tfhub_modules/e40ef097142ae1de637df7021ce148ffe836e262/variables/variables' with embeddings
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-09-28-18:29:25
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from content_based_model_trained/model.ckpt-186
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-09-28-18:30:21
# INFO:tensorflow:Saving dict for global step 186: accuracy = 0.03093871, global_step = 186, loss = 5.297491, top_10_accuracy = 0.23536076
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Initialize variable input_layer/title_hub_module_embedding/module/embeddings/part_0:0 from checkpoint b'/tmp/tfhub_modules/e40ef097142ae1de637df7021ce148ffe836e262/variables/variables' with embeddings
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from content_based_model_trained/model.ckpt-186
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 187 into content_based_model_trained/model.ckpt.
# INFO:tensorflow:loss = 5.2358155, step = 187
# INFO:tensorflow:Saving checkpoints for 227 into content_based_model_trained/model.ckpt.
# INFO:tensorflow:Loss for final step: 5.175952.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Initialize variable input_layer/title_hub_module_embedding/module/embeddings/part_0:0 from checkpoint b'/tmp/tfhub_modules/e40ef097142ae1de637df7021ce148ffe836e262/variables/variables' with embeddings
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-09-28-18:31:32
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from content_based_model_trained/model.ckpt-227
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-09-28-18:32:16
# INFO:tensorflow:Saving dict for global step 227: accuracy = 0.032774717, global_step = 227, loss = 5.2634416, top_10_accuracy = 0.23403259
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Initialize variable input_layer/title_hub_module_embedding/module/embeddings/part_0:0 from checkpoint b'/tmp/tfhub_modules/e40ef097142ae1de637df7021ce148ffe836e262/variables/variables' with embeddings
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from content_based_model_trained/model.ckpt-227
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 228 into content_based_model_trained/model.ckpt.
# INFO:tensorflow:loss = 5.2318707, step = 228
# INFO:tensorflow:Saving checkpoints for 270 into content_based_model_trained/model.ckpt.
# INFO:tensorflow:Loss for final step: 5.2088895.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Initialize variable input_layer/title_hub_module_embedding/module/embeddings/part_0:0 from checkpoint b'/tmp/tfhub_modules/e40ef097142ae1de637df7021ce148ffe836e262/variables/variables' with embeddings
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-09-28-18:33:27
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from content_based_model_trained/model.ckpt-270
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-09-28-18:34:11
# INFO:tensorflow:Saving dict for global step 270: accuracy = 0.031798117, global_step = 270, loss = 5.241289, top_10_accuracy = 0.23141529
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Initialize variable input_layer/title_hub_module_embedding/module/embeddings/part_0:0 from checkpoint b'/tmp/tfhub_modules/e40ef097142ae1de637df7021ce148ffe836e262/variables/variables' with embeddings
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from content_based_model_trained/model.ckpt-270
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 271 into content_based_model_trained/model.ckpt.
# INFO:tensorflow:loss = 5.0803027, step = 271
# INFO:tensorflow:Saving checkpoints for 310 into content_based_model_trained/model.ckpt.
# INFO:tensorflow:Loss for final step: 5.2432246.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Initialize variable input_layer/title_hub_module_embedding/module/embeddings/part_0:0 from checkpoint b'/tmp/tfhub_modules/e40ef097142ae1de637df7021ce148ffe836e262/variables/variables' with embeddings
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-09-28-18:35:22
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from content_based_model_trained/model.ckpt-310
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-09-28-18:36:05
# INFO:tensorflow:Saving dict for global step 310: accuracy = 0.022149302, global_step = 310, loss = 5.227738, top_10_accuracy = 0.23106371
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Initialize variable input_layer/title_hub_module_embedding/module/embeddings/part_0:0 from checkpoint b'/tmp/tfhub_modules/e40ef097142ae1de637df7021ce148ffe836e262/variables/variables' with embeddings
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from content_based_model_trained/model.ckpt-310
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 311 into content_based_model_trained/model.ckpt.
# INFO:tensorflow:loss = 5.1685457, step = 311
# INFO:tensorflow:Saving checkpoints for 355 into content_based_model_trained/model.ckpt.
# INFO:tensorflow:Loss for final step: 5.1808414.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Initialize variable input_layer/title_hub_module_embedding/module/embeddings/part_0:0 from checkpoint b'/tmp/tfhub_modules/e40ef097142ae1de637df7021ce148ffe836e262/variables/variables' with embeddings
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-09-28-18:37:16
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from content_based_model_trained/model.ckpt-355
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-09-28-18:37:58
# INFO:tensorflow:Saving dict for global step 355: accuracy = 0.0236728, global_step = 355, loss = 5.2066455, top_10_accuracy = 0.24309543
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Initialize variable input_layer/title_hub_module_embedding/module/embeddings/part_0:0 from checkpoint b'/tmp/tfhub_modules/e40ef097142ae1de637df7021ce148ffe836e262/variables/variables' with embeddings
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from content_based_model_trained/model.ckpt-355
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 356 into content_based_model_trained/model.ckpt.
# INFO:tensorflow:loss = 5.166778, step = 356
# INFO:tensorflow:Saving checkpoints for 380 into content_based_model_trained/model.ckpt.
# INFO:tensorflow:Loss for final step: 5.0338664.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Initialize variable input_layer/title_hub_module_embedding/module/embeddings/part_0:0 from checkpoint b'/tmp/tfhub_modules/e40ef097142ae1de637df7021ce148ffe836e262/variables/variables' with embeddings
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-09-28-18:39:14
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from content_based_model_trained/model.ckpt-380
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-09-28-18:40:21
# INFO:tensorflow:Saving dict for global step 380: accuracy = 0.029610531, global_step = 380, loss = 5.192317, top_10_accuracy = 0.25200203
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Initialize variable input_layer/title_hub_module_embedding/module/embeddings/part_0:0 from checkpoint b'/tmp/tfhub_modules/e40ef097142ae1de637df7021ce148ffe836e262/variables/variables' with embeddings
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from content_based_model_trained/model.ckpt-380
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 381 into content_based_model_trained/model.ckpt.
# INFO:tensorflow:loss = 5.168992, step = 381
# INFO:tensorflow:Saving checkpoints for 404 into content_based_model_trained/model.ckpt.
# INFO:tensorflow:Loss for final step: 5.055147.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Initialize variable input_layer/title_hub_module_embedding/module/embeddings/part_0:0 from checkpoint b'/tmp/tfhub_modules/e40ef097142ae1de637df7021ce148ffe836e262/variables/variables' with embeddings
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-09-28-18:41:36
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from content_based_model_trained/model.ckpt-404
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-09-28-18:42:41
# INFO:tensorflow:Saving dict for global step 404: accuracy = 0.028438611, global_step = 404, loss = 5.200553, top_10_accuracy = 0.24305637
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Initialize variable input_layer/title_hub_module_embedding/module/embeddings/part_0:0 from checkpoint b'/tmp/tfhub_modules/e40ef097142ae1de637df7021ce148ffe836e262/variables/variables' with embeddings
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from content_based_model_trained/model.ckpt-404
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 405 into content_based_model_trained/model.ckpt.
# INFO:tensorflow:loss = 5.104851, step = 405
# INFO:tensorflow:Saving checkpoints for 430 into content_based_model_trained/model.ckpt.
# INFO:tensorflow:Loss for final step: 5.0455165.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Initialize variable input_layer/title_hub_module_embedding/module/embeddings/part_0:0 from checkpoint b'/tmp/tfhub_modules/e40ef097142ae1de637df7021ce148ffe836e262/variables/variables' with embeddings
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-09-28-18:43:59
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from content_based_model_trained/model.ckpt-430
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-09-28-18:44:49
# INFO:tensorflow:Saving dict for global step 430: accuracy = 0.037774913, global_step = 430, loss = 5.1857104, top_10_accuracy = 0.255635
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Initialize variable input_layer/title_hub_module_embedding/module/embeddings/part_0:0 from checkpoint b'/tmp/tfhub_modules/e40ef097142ae1de637df7021ce148ffe836e262/variables/variables' with embeddings
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from content_based_model_trained/model.ckpt-430
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 431 into content_based_model_trained/model.ckpt.
# INFO:tensorflow:loss = 5.123452, step = 431
# INFO:tensorflow:Saving checkpoints for 471 into content_based_model_trained/model.ckpt.
# INFO:tensorflow:Loss for final step: 5.144367.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Initialize variable input_layer/title_hub_module_embedding/module/embeddings/part_0:0 from checkpoint b'/tmp/tfhub_modules/e40ef097142ae1de637df7021ce148ffe836e262/variables/variables' with embeddings
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-09-28-18:45:59
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from content_based_model_trained/model.ckpt-471
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-09-28-18:46:43
# INFO:tensorflow:Saving dict for global step 471: accuracy = 0.034024768, global_step = 471, loss = 5.169789, top_10_accuracy = 0.2548537
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Initialize variable input_layer/title_hub_module_embedding/module/embeddings/part_0:0 from checkpoint b'/tmp/tfhub_modules/e40ef097142ae1de637df7021ce148ffe836e262/variables/variables' with embeddings
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from content_based_model_trained/model.ckpt-471
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 472 into content_based_model_trained/model.ckpt.
# INFO:tensorflow:loss = 4.9766417, step = 472
# INFO:tensorflow:Saving checkpoints for 512 into content_based_model_trained/model.ckpt.
# INFO:tensorflow:Loss for final step: 5.088978.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Initialize variable input_layer/title_hub_module_embedding/module/embeddings/part_0:0 from checkpoint b'/tmp/tfhub_modules/e40ef097142ae1de637df7021ce148ffe836e262/variables/variables' with embeddings
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-09-28-18:47:54
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from content_based_model_trained/model.ckpt-512
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-09-28-18:48:53
# INFO:tensorflow:Saving dict for global step 512: accuracy = 0.04152506, global_step = 512, loss = 5.160522, top_10_accuracy = 0.2622368
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Initialize variable input_layer/title_hub_module_embedding/module/embeddings/part_0:0 from checkpoint b'/tmp/tfhub_modules/e40ef097142ae1de637df7021ce148ffe836e262/variables/variables' with embeddings
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from content_based_model_trained/model.ckpt-512
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 513 into content_based_model_trained/model.ckpt.
# INFO:tensorflow:loss = 5.043599, step = 513
# INFO:tensorflow:Saving checkpoints for 537 into content_based_model_trained/model.ckpt.
# INFO:tensorflow:Loss for final step: 5.0731735.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Initialize variable input_layer/title_hub_module_embedding/module/embeddings/part_0:0 from checkpoint b'/tmp/tfhub_modules/e40ef097142ae1de637df7021ce148ffe836e262/variables/variables' with embeddings
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-09-28-18:50:10
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from content_based_model_trained/model.ckpt-537
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-09-28-18:51:17
# INFO:tensorflow:Saving dict for global step 537: accuracy = 0.033634126, global_step = 537, loss = 5.160396, top_10_accuracy = 0.25504902
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Initialize variable input_layer/title_hub_module_embedding/module/embeddings/part_0:0 from checkpoint b'/tmp/tfhub_modules/e40ef097142ae1de637df7021ce148ffe836e262/variables/variables' with embeddings
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from content_based_model_trained/model.ckpt-537
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 538 into content_based_model_trained/model.ckpt.
# INFO:tensorflow:loss = 5.067943, step = 538
# INFO:tensorflow:Saving checkpoints for 561 into content_based_model_trained/model.ckpt.
# INFO:tensorflow:Loss for final step: 5.0821733.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Initialize variable input_layer/title_hub_module_embedding/module/embeddings/part_0:0 from checkpoint b'/tmp/tfhub_modules/e40ef097142ae1de637df7021ce148ffe836e262/variables/variables' with embeddings
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-09-28-18:52:32
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from content_based_model_trained/model.ckpt-561
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-09-28-18:53:35
# INFO:tensorflow:Saving dict for global step 561: accuracy = 0.038868707, global_step = 561, loss = 5.160089, top_10_accuracy = 0.2549709
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Initialize variable input_layer/title_hub_module_embedding/module/embeddings/part_0:0 from checkpoint b'/tmp/tfhub_modules/e40ef097142ae1de637df7021ce148ffe836e262/variables/variables' with embeddings
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from content_based_model_trained/model.ckpt-561
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 562 into content_based_model_trained/model.ckpt.
# INFO:tensorflow:loss = 5.0460644, step = 562
# INFO:tensorflow:Saving checkpoints for 585 into content_based_model_trained/model.ckpt.
# INFO:tensorflow:Loss for final step: 4.948985.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Initialize variable input_layer/title_hub_module_embedding/module/embeddings/part_0:0 from checkpoint b'/tmp/tfhub_modules/e40ef097142ae1de637df7021ce148ffe836e262/variables/variables' with embeddings
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-09-28-18:54:51
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from content_based_model_trained/model.ckpt-585
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-09-28-18:56:06
# INFO:tensorflow:Saving dict for global step 585: accuracy = 0.037970234, global_step = 585, loss = 5.159715, top_10_accuracy = 0.2529005
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Initialize variable input_layer/title_hub_module_embedding/module/embeddings/part_0:0 from checkpoint b'/tmp/tfhub_modules/e40ef097142ae1de637df7021ce148ffe836e262/variables/variables' with embeddings
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from content_based_model_trained/model.ckpt-585
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 586 into content_based_model_trained/model.ckpt.
# INFO:tensorflow:loss = 4.9470587, step = 586
# INFO:tensorflow:Saving checkpoints for 608 into content_based_model_trained/model.ckpt.
# INFO:tensorflow:Loss for final step: 5.1515865.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Initialize variable input_layer/title_hub_module_embedding/module/embeddings/part_0:0 from checkpoint b'/tmp/tfhub_modules/e40ef097142ae1de637df7021ce148ffe836e262/variables/variables' with embeddings
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-09-28-18:57:23
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from content_based_model_trained/model.ckpt-608
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-09-28-18:58:18
# INFO:tensorflow:Saving dict for global step 608: accuracy = 0.031602796, global_step = 608, loss = 5.1561475, top_10_accuracy = 0.2596195
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Initialize variable input_layer/title_hub_module_embedding/module/embeddings/part_0:0 from checkpoint b'/tmp/tfhub_modules/e40ef097142ae1de637df7021ce148ffe836e262/variables/variables' with embeddings
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from content_based_model_trained/model.ckpt-608
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 609 into content_based_model_trained/model.ckpt.
# INFO:tensorflow:loss = 5.0045915, step = 609
# INFO:tensorflow:Saving checkpoints for 631 into content_based_model_trained/model.ckpt.
# INFO:tensorflow:Loss for final step: 5.009101.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Initialize variable input_layer/title_hub_module_embedding/module/embeddings/part_0:0 from checkpoint b'/tmp/tfhub_modules/e40ef097142ae1de637df7021ce148ffe836e262/variables/variables' with embeddings
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-09-28-18:59:33
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from content_based_model_trained/model.ckpt-631
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-09-28-19:00:39
# INFO:tensorflow:Saving dict for global step 631: accuracy = 0.039845306, global_step = 631, loss = 5.153938, top_10_accuracy = 0.26001015
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Initialize variable input_layer/title_hub_module_embedding/module/embeddings/part_0:0 from checkpoint b'/tmp/tfhub_modules/e40ef097142ae1de637df7021ce148ffe836e262/variables/variables' with embeddings
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from content_based_model_trained/model.ckpt-631
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 632 into content_based_model_trained/model.ckpt.
# INFO:tensorflow:loss = 4.8804126, step = 632
# INFO:tensorflow:Saving checkpoints for 656 into content_based_model_trained/model.ckpt.
# INFO:tensorflow:Loss for final step: 5.005497.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Initialize variable input_layer/title_hub_module_embedding/module/embeddings/part_0:0 from checkpoint b'/tmp/tfhub_modules/e40ef097142ae1de637df7021ce148ffe836e262/variables/variables' with embeddings
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-09-28-19:01:59
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from content_based_model_trained/model.ckpt-656
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-09-28-19:03:05
# INFO:tensorflow:Saving dict for global step 656: accuracy = 0.038829643, global_step = 656, loss = 5.1369476, top_10_accuracy = 0.27032307
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Initialize variable input_layer/title_hub_module_embedding/module/embeddings/part_0:0 from checkpoint b'/tmp/tfhub_modules/e40ef097142ae1de637df7021ce148ffe836e262/variables/variables' with embeddings
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from content_based_model_trained/model.ckpt-656
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 657 into content_based_model_trained/model.ckpt.
# INFO:tensorflow:loss = 4.8672814, step = 657
# INFO:tensorflow:Saving checkpoints for 680 into content_based_model_trained/model.ckpt.
# INFO:tensorflow:Loss for final step: 4.844594.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Initialize variable input_layer/title_hub_module_embedding/module/embeddings/part_0:0 from checkpoint b'/tmp/tfhub_modules/e40ef097142ae1de637df7021ce148ffe836e262/variables/variables' with embeddings
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-09-28-19:04:20
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from content_based_model_trained/model.ckpt-680
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-09-28-19:05:29
# INFO:tensorflow:Saving dict for global step 680: accuracy = 0.04156412, global_step = 680, loss = 5.1384516, top_10_accuracy = 0.2675495
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Initialize variable input_layer/title_hub_module_embedding/module/embeddings/part_0:0 from checkpoint b'/tmp/tfhub_modules/e40ef097142ae1de637df7021ce148ffe836e262/variables/variables' with embeddings
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from content_based_model_trained/model.ckpt-680
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 681 into content_based_model_trained/model.ckpt.
# INFO:tensorflow:loss = 4.8499737, step = 681
# INFO:tensorflow:Saving checkpoints for 705 into content_based_model_trained/model.ckpt.
# INFO:tensorflow:Loss for final step: 5.029001.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Initialize variable input_layer/title_hub_module_embedding/module/embeddings/part_0:0 from checkpoint b'/tmp/tfhub_modules/e40ef097142ae1de637df7021ce148ffe836e262/variables/variables' with embeddings
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-09-28-19:06:46
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from content_based_model_trained/model.ckpt-705
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-09-28-19:07:38
# INFO:tensorflow:Saving dict for global step 705: accuracy = 0.03609516, global_step = 705, loss = 5.13367, top_10_accuracy = 0.26665103
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Initialize variable input_layer/title_hub_module_embedding/module/embeddings/part_0:0 from checkpoint b'/tmp/tfhub_modules/e40ef097142ae1de637df7021ce148ffe836e262/variables/variables' with embeddings
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from content_based_model_trained/model.ckpt-705
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 706 into content_based_model_trained/model.ckpt.
# INFO:tensorflow:loss = 4.9471483, step = 706
# INFO:tensorflow:Saving checkpoints for 734 into content_based_model_trained/model.ckpt.
# INFO:tensorflow:Loss for final step: 5.023178.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Initialize variable input_layer/title_hub_module_embedding/module/embeddings/part_0:0 from checkpoint b'/tmp/tfhub_modules/e40ef097142ae1de637df7021ce148ffe836e262/variables/variables' with embeddings
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-09-28-19:08:55
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from content_based_model_trained/model.ckpt-734
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-09-28-19:10:05
# INFO:tensorflow:Saving dict for global step 734: accuracy = 0.04242353, global_step = 734, loss = 5.1331434, top_10_accuracy = 0.2757139
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Initialize variable input_layer/title_hub_module_embedding/module/embeddings/part_0:0 from checkpoint b'/tmp/tfhub_modules/e40ef097142ae1de637df7021ce148ffe836e262/variables/variables' with embeddings
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from content_based_model_trained/model.ckpt-734
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 735 into content_based_model_trained/model.ckpt.
# INFO:tensorflow:loss = 4.874956, step = 735
# INFO:tensorflow:Saving checkpoints for 754 into content_based_model_trained/model.ckpt.
# INFO:tensorflow:Loss for final step: 4.9341073.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Initialize variable input_layer/title_hub_module_embedding/module/embeddings/part_0:0 from checkpoint b'/tmp/tfhub_modules/e40ef097142ae1de637df7021ce148ffe836e262/variables/variables' with embeddings
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-09-28-19:11:24
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from content_based_model_trained/model.ckpt-754
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-09-28-19:12:32
# INFO:tensorflow:Saving dict for global step 754: accuracy = 0.040821906, global_step = 754, loss = 5.13299, top_10_accuracy = 0.27227625
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Initialize variable input_layer/title_hub_module_embedding/module/embeddings/part_0:0 from checkpoint b'/tmp/tfhub_modules/e40ef097142ae1de637df7021ce148ffe836e262/variables/variables' with embeddings
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from content_based_model_trained/model.ckpt-754
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 755 into content_based_model_trained/model.ckpt.
# INFO:tensorflow:loss = 4.885724, step = 755
# INFO:tensorflow:Saving checkpoints for 778 into content_based_model_trained/model.ckpt.
# INFO:tensorflow:Loss for final step: 4.9477406.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Initialize variable input_layer/title_hub_module_embedding/module/embeddings/part_0:0 from checkpoint b'/tmp/tfhub_modules/e40ef097142ae1de637df7021ce148ffe836e262/variables/variables' with embeddings
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-09-28-19:13:51
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from content_based_model_trained/model.ckpt-778
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-09-28-19:15:00
# INFO:tensorflow:Saving dict for global step 778: accuracy = 0.041485995, global_step = 778, loss = 5.131723, top_10_accuracy = 0.2777843
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Initialize variable input_layer/title_hub_module_embedding/module/embeddings/part_0:0 from checkpoint b'/tmp/tfhub_modules/e40ef097142ae1de637df7021ce148ffe836e262/variables/variables' with embeddings
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from content_based_model_trained/model.ckpt-778
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 779 into content_based_model_trained/model.ckpt.
# INFO:tensorflow:loss = 4.8656282, step = 779
# INFO:tensorflow:Saving checkpoints for 803 into content_based_model_trained/model.ckpt.
# INFO:tensorflow:Loss for final step: 4.818345.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Initialize variable input_layer/title_hub_module_embedding/module/embeddings/part_0:0 from checkpoint b'/tmp/tfhub_modules/e40ef097142ae1de637df7021ce148ffe836e262/variables/variables' with embeddings
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-09-28-19:16:18
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from content_based_model_trained/model.ckpt-803
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-09-28-19:17:07
# INFO:tensorflow:Saving dict for global step 803: accuracy = 0.036056098, global_step = 803, loss = 5.1349087, top_10_accuracy = 0.27176842
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Initialize variable input_layer/title_hub_module_embedding/module/embeddings/part_0:0 from checkpoint b'/tmp/tfhub_modules/e40ef097142ae1de637df7021ce148ffe836e262/variables/variables' with embeddings
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from content_based_model_trained/model.ckpt-803
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 804 into content_based_model_trained/model.ckpt.
# INFO:tensorflow:loss = 4.923583, step = 804
# INFO:tensorflow:Saving checkpoints for 842 into content_based_model_trained/model.ckpt.
# INFO:tensorflow:Loss for final step: 5.0419245.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Initialize variable input_layer/title_hub_module_embedding/module/embeddings/part_0:0 from checkpoint b'/tmp/tfhub_modules/e40ef097142ae1de637df7021ce148ffe836e262/variables/variables' with embeddings
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-09-28-19:18:22
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from content_based_model_trained/model.ckpt-842
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-09-28-19:19:26
# INFO:tensorflow:Saving dict for global step 842: accuracy = 0.039845306, global_step = 842, loss = 5.1141906, top_10_accuracy = 0.27637798
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Initialize variable input_layer/title_hub_module_embedding/module/embeddings/part_0:0 from checkpoint b'/tmp/tfhub_modules/e40ef097142ae1de637df7021ce148ffe836e262/variables/variables' with embeddings
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from content_based_model_trained/model.ckpt-842
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 843 into content_based_model_trained/model.ckpt.
# INFO:tensorflow:loss = 4.9145274, step = 843
# INFO:tensorflow:Saving checkpoints for 866 into content_based_model_trained/model.ckpt.
# INFO:tensorflow:Loss for final step: 4.9566526.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Initialize variable input_layer/title_hub_module_embedding/module/embeddings/part_0:0 from checkpoint b'/tmp/tfhub_modules/e40ef097142ae1de637df7021ce148ffe836e262/variables/variables' with embeddings
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-09-28-19:20:43
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from content_based_model_trained/model.ckpt-866
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-09-28-19:21:51
# INFO:tensorflow:Saving dict for global step 866: accuracy = 0.04511895, global_step = 866, loss = 5.1048546, top_10_accuracy = 0.28044063
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Initialize variable input_layer/title_hub_module_embedding/module/embeddings/part_0:0 from checkpoint b'/tmp/tfhub_modules/e40ef097142ae1de637df7021ce148ffe836e262/variables/variables' with embeddings
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from content_based_model_trained/model.ckpt-866
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 867 into content_based_model_trained/model.ckpt.
# INFO:tensorflow:loss = 4.8765364, step = 867
# INFO:tensorflow:Saving checkpoints for 890 into content_based_model_trained/model.ckpt.
# INFO:tensorflow:Loss for final step: 4.8178453.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Initialize variable input_layer/title_hub_module_embedding/module/embeddings/part_0:0 from checkpoint b'/tmp/tfhub_modules/e40ef097142ae1de637df7021ce148ffe836e262/variables/variables' with embeddings
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-09-28-19:23:06
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from content_based_model_trained/model.ckpt-890
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-09-28-19:24:14
# INFO:tensorflow:Saving dict for global step 890: accuracy = 0.041368805, global_step = 890, loss = 5.1091957, top_10_accuracy = 0.28376108
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Initialize variable input_layer/title_hub_module_embedding/module/embeddings/part_0:0 from checkpoint b'/tmp/tfhub_modules/e40ef097142ae1de637df7021ce148ffe836e262/variables/variables' with embeddings
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from content_based_model_trained/model.ckpt-890
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 891 into content_based_model_trained/model.ckpt.
# INFO:tensorflow:loss = 4.881337, step = 891
# INFO:tensorflow:Saving checkpoints for 914 into content_based_model_trained/model.ckpt.
# INFO:tensorflow:Loss for final step: 4.8397284.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Initialize variable input_layer/title_hub_module_embedding/module/embeddings/part_0:0 from checkpoint b'/tmp/tfhub_modules/e40ef097142ae1de637df7021ce148ffe836e262/variables/variables' with embeddings
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-09-28-19:25:31
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from content_based_model_trained/model.ckpt-914
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-09-28-19:26:36
# INFO:tensorflow:Saving dict for global step 914: accuracy = 0.03976718, global_step = 914, loss = 5.111272, top_10_accuracy = 0.28032345
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Initialize variable input_layer/title_hub_module_embedding/module/embeddings/part_0:0 from checkpoint b'/tmp/tfhub_modules/e40ef097142ae1de637df7021ce148ffe836e262/variables/variables' with embeddings
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from content_based_model_trained/model.ckpt-914
# ...
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-09-28-20:26:56
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from content_based_model_trained/model.ckpt-1581
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-09-28-20:27:58
# INFO:tensorflow:Saving dict for global step 1581: accuracy = 0.048361264, global_step = 1581, loss = 5.055956, top_10_accuracy = 0.30661353
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Initialize variable input_layer/title_hub_module_embedding/module/embeddings/part_0:0 from checkpoint b'/tmp/tfhub_modules/e40ef097142ae1de637df7021ce148ffe836e262/variables/variables' with embeddings
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from content_based_model_trained/model.ckpt-1581
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 1582 into content_based_model_trained/model.ckpt.
# INFO:tensorflow:loss = 4.5524387, step = 1582
# INFO:tensorflow:Saving checkpoints for 1606 into content_based_model_trained/model.ckpt.
# INFO:tensorflow:Loss for final step: 4.7935343.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Initialize variable input_layer/title_hub_module_embedding/module/embeddings/part_0:0 from checkpoint b'/tmp/tfhub_modules/e40ef097142ae1de637df7021ce148ffe836e262/variables/variables' with embeddings
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-09-28-20:29:12
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from content_based_model_trained/model.ckpt-1606
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-09-28-20:30:12
# INFO:tensorflow:Saving dict for global step 1606: accuracy = 0.050041016, global_step = 1606, loss = 5.0528913, top_10_accuracy = 0.30258995
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Initialize variable input_layer/title_hub_module_embedding/module/embeddings/part_0:0 from checkpoint b'/tmp/tfhub_modules/e40ef097142ae1de637df7021ce148ffe836e262/variables/variables' with embeddings
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from content_based_model_trained/model.ckpt-1606
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 1607 into content_based_model_trained/model.ckpt.
# INFO:tensorflow:loss = 4.601652, step = 1607
# INFO:tensorflow:Saving checkpoints for 1634 into content_based_model_trained/model.ckpt.
# INFO:tensorflow:Loss for final step: 4.6875553.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Initialize variable input_layer/title_hub_module_embedding/module/embeddings/part_0:0 from checkpoint b'/tmp/tfhub_modules/e40ef097142ae1de637df7021ce148ffe836e262/variables/variables' with embeddings
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-09-28-20:31:28
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from content_based_model_trained/model.ckpt-1634
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-09-28-20:32:28
# INFO:tensorflow:Saving dict for global step 1634: accuracy = 0.04660338, global_step = 1634, loss = 5.049248, top_10_accuracy = 0.31020743
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Initialize variable input_layer/title_hub_module_embedding/module/embeddings/part_0:0 from checkpoint b'/tmp/tfhub_modules/e40ef097142ae1de637df7021ce148ffe836e262/variables/variables' with embeddings
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from content_based_model_trained/model.ckpt-1634
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 1635 into content_based_model_trained/model.ckpt.
# INFO:tensorflow:loss = 4.6492095, step = 1635
# INFO:tensorflow:Saving checkpoints for 1659 into content_based_model_trained/model.ckpt.
# INFO:tensorflow:Loss for final step: 4.784423.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Initialize variable input_layer/title_hub_module_embedding/module/embeddings/part_0:0 from checkpoint b'/tmp/tfhub_modules/e40ef097142ae1de637df7021ce148ffe836e262/variables/variables' with embeddings
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-09-28-20:33:41
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from content_based_model_trained/model.ckpt-1659
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-09-28-20:34:43
# INFO:tensorflow:Saving dict for global step 1659: accuracy = 0.049884763, global_step = 1659, loss = 5.053564, top_10_accuracy = 0.31009024
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Initialize variable input_layer/title_hub_module_embedding/module/embeddings/part_0:0 from checkpoint b'/tmp/tfhub_modules/e40ef097142ae1de637df7021ce148ffe836e262/variables/variables' with embeddings
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from content_based_model_trained/model.ckpt-1659
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 1660 into content_based_model_trained/model.ckpt.
# INFO:tensorflow:loss = 4.622185, step = 1660
# INFO:tensorflow:Saving checkpoints for 1686 into content_based_model_trained/model.ckpt.
# INFO:tensorflow:Loss for final step: 4.8687944.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Initialize variable input_layer/title_hub_module_embedding/module/embeddings/part_0:0 from checkpoint b'/tmp/tfhub_modules/e40ef097142ae1de637df7021ce148ffe836e262/variables/variables' with embeddings
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-09-28-20:35:58
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from content_based_model_trained/model.ckpt-1686
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-09-28-20:36:59
# INFO:tensorflow:Saving dict for global step 1686: accuracy = 0.049455058, global_step = 1686, loss = 5.0509276, top_10_accuracy = 0.30509004
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Initialize variable input_layer/title_hub_module_embedding/module/embeddings/part_0:0 from checkpoint b'/tmp/tfhub_modules/e40ef097142ae1de637df7021ce148ffe836e262/variables/variables' with embeddings
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from content_based_model_trained/model.ckpt-1686
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 1687 into content_based_model_trained/model.ckpt.
# INFO:tensorflow:loss = 4.5512486, step = 1687
# INFO:tensorflow:Saving checkpoints for 1717 into content_based_model_trained/model.ckpt.
# INFO:tensorflow:Loss for final step: 4.9125433.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Initialize variable input_layer/title_hub_module_embedding/module/embeddings/part_0:0 from checkpoint b'/tmp/tfhub_modules/e40ef097142ae1de637df7021ce148ffe836e262/variables/variables' with embeddings
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-09-28-20:38:12
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from content_based_model_trained/model.ckpt-1717
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-09-28-20:39:16
# INFO:tensorflow:Saving dict for global step 1717: accuracy = 0.051837962, global_step = 1717, loss = 5.040951, top_10_accuracy = 0.31020743
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Initialize variable input_layer/title_hub_module_embedding/module/embeddings/part_0:0 from checkpoint b'/tmp/tfhub_modules/e40ef097142ae1de637df7021ce148ffe836e262/variables/variables' with embeddings
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from content_based_model_trained/model.ckpt-1717
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 1718 into content_based_model_trained/model.ckpt.
# INFO:tensorflow:loss = 4.612566, step = 1718
# INFO:tensorflow:Saving checkpoints for 1744 into content_based_model_trained/model.ckpt.
# INFO:tensorflow:Loss for final step: 4.77433.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Initialize variable input_layer/title_hub_module_embedding/module/embeddings/part_0:0 from checkpoint b'/tmp/tfhub_modules/e40ef097142ae1de637df7021ce148ffe836e262/variables/variables' with embeddings
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-09-28-20:40:31
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from content_based_model_trained/model.ckpt-1744
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-09-28-20:41:37
# INFO:tensorflow:Saving dict for global step 1744: accuracy = 0.049455058, global_step = 1744, loss = 5.043204, top_10_accuracy = 0.31184813
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Initialize variable input_layer/title_hub_module_embedding/module/embeddings/part_0:0 from checkpoint b'/tmp/tfhub_modules/e40ef097142ae1de637df7021ce148ffe836e262/variables/variables' with embeddings
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from content_based_model_trained/model.ckpt-1744
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 1745 into content_based_model_trained/model.ckpt.
# INFO:tensorflow:loss = 4.635585, step = 1745
# INFO:tensorflow:Saving checkpoints for 1768 into content_based_model_trained/model.ckpt.
# INFO:tensorflow:Loss for final step: 4.669032.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Initialize variable input_layer/title_hub_module_embedding/module/embeddings/part_0:0 from checkpoint b'/tmp/tfhub_modules/e40ef097142ae1de637df7021ce148ffe836e262/variables/variables' with embeddings
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-09-28-20:42:51
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from content_based_model_trained/model.ckpt-1768
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-09-28-20:43:57
# INFO:tensorflow:Saving dict for global step 1768: accuracy = 0.049337864, global_step = 1768, loss = 5.053097, top_10_accuracy = 0.31098872
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Initialize variable input_layer/title_hub_module_embedding/module/embeddings/part_0:0 from checkpoint b'/tmp/tfhub_modules/e40ef097142ae1de637df7021ce148ffe836e262/variables/variables' with embeddings
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from content_based_model_trained/model.ckpt-1768
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 1769 into content_based_model_trained/model.ckpt.
# INFO:tensorflow:loss = 4.635854, step = 1769
# INFO:tensorflow:Saving checkpoints for 1793 into content_based_model_trained/model.ckpt.
# INFO:tensorflow:Loss for final step: 4.7237873.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Initialize variable input_layer/title_hub_module_embedding/module/embeddings/part_0:0 from checkpoint b'/tmp/tfhub_modules/e40ef097142ae1de637df7021ce148ffe836e262/variables/variables' with embeddings
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-09-28-20:45:14
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from content_based_model_trained/model.ckpt-1793
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-09-28-20:46:19
# INFO:tensorflow:Saving dict for global step 1793: accuracy = 0.048205007, global_step = 1793, loss = 5.060227, top_10_accuracy = 0.30981678
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Initialize variable input_layer/title_hub_module_embedding/module/embeddings/part_0:0 from checkpoint b'/tmp/tfhub_modules/e40ef097142ae1de637df7021ce148ffe836e262/variables/variables' with embeddings
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from content_based_model_trained/model.ckpt-1793
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 1794 into content_based_model_trained/model.ckpt.
# INFO:tensorflow:loss = 4.608535, step = 1794
# INFO:tensorflow:Saving checkpoints for 1819 into content_based_model_trained/model.ckpt.
# INFO:tensorflow:Loss for final step: 4.719972.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Initialize variable input_layer/title_hub_module_embedding/module/embeddings/part_0:0 from checkpoint b'/tmp/tfhub_modules/e40ef097142ae1de637df7021ce148ffe836e262/variables/variables' with embeddings
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-09-28-20:47:36
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from content_based_model_trained/model.ckpt-1819
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-09-28-20:48:32
# INFO:tensorflow:Saving dict for global step 1819: accuracy = 0.049259737, global_step = 1819, loss = 5.0564303, top_10_accuracy = 0.3054807
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Initialize variable input_layer/title_hub_module_embedding/module/embeddings/part_0:0 from checkpoint b'/tmp/tfhub_modules/e40ef097142ae1de637df7021ce148ffe836e262/variables/variables' with embeddings
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from content_based_model_trained/model.ckpt-1819
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 1820 into content_based_model_trained/model.ckpt.
# INFO:tensorflow:loss = 4.56242, step = 1820
# INFO:tensorflow:Saving checkpoints for 1842 into content_based_model_trained/model.ckpt.
# INFO:tensorflow:Loss for final step: 4.6010613.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Initialize variable input_layer/title_hub_module_embedding/module/embeddings/part_0:0 from checkpoint b'/tmp/tfhub_modules/e40ef097142ae1de637df7021ce148ffe836e262/variables/variables' with embeddings
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-09-28-20:49:46
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from content_based_model_trained/model.ckpt-1842
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.

# %% [markdown]
# This takes a while to complete but in the end, I get about **30% top 10 accuracy**.

# %% [markdown]
# ### Make predictions with the trained model.
#
# With the model now trained, we can make predictions by calling the predict method on the estimator. Let's look at how our model predicts on the first five examples of the training set.
# To start, we'll create a new file 'first_5.csv' which contains the first five elements of our training set. We'll also save the target values to a file 'first_5_content_ids' so we can compare our results.

# %%
# %%bash
# head -5 training_set.csv > first_5.csv
# head first_5.csv
# awk -F "\"*,\"*" '{print $2}' first_5.csv > first_5_content_ids
# Out:
# 1004555043399129313,299833840,News,"Ehemalige Obdachlose: ""Für mich war die Gruft eine Familie""",Julia Schrenk,574,299837992
# 1004555043399129313,299837992,Stars & Kultur,Das erste TV-Interview von Prinz Harry & Meghan Markle ,Christina Michlits,574,299824032
# 1004555043399129313,299824032,Stars & Kultur,YouTube: Schwere Probleme mit verstörenden Kindervideos,Georg Leyrer,574,299836255
# 1004555043399129313,299836255,News,Blümel Kneissl &Co.: Das sind die Fixstarter,,574,299836841
# 1004555043399129313,299836841,News,"ÖVP will Studiengebühren FPÖ in Verhandlungen ""flexibel""",Raffaela Lindorfer,574,299899819

# %% [markdown]
# Recall, to make predictions on the trained model we pass a list of examples through the input function. Complete the code below to make predicitons on the examples contained in the "first_5.csv" file we created above.

# %%
output = list(estimator.predict(input_fn=read_dataset("first_5.csv", tf.estimator.ModeKeys.PREDICT)))
# Out:
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Initialize variable input_layer/title_hub_module_embedding/module/embeddings/part_0:0 from checkpoint b'/tmp/tfhub_modules/e40ef097142ae1de637df7021ce148ffe836e262/variables/variables' with embeddings
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from content_based_model_trained/model.ckpt-500
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.

# %%
import numpy as np
recommended_content_ids = [np.asscalar(d["class_names"]).decode('UTF-8') for d in output]
content_ids = open("first_5_content_ids").read().splitlines()

# %% [markdown]
# Finally, we map the content id back to the article title. Let's compare our model's recommendation for the first example. This can be done in BigQuery. Look through the query below and make sure it is clear what is being returned.

# %%
import google.datalab.bigquery as bq
recommended_title_sql="""
#standardSQL
SELECT
(SELECT MAX(IF(index=6, value, NULL)) FROM UNNEST(hits.customDimensions)) AS title
FROM `cloud-training-demos.GA360_test.ga_sessions_sample`,   
  UNNEST(hits) AS hits
WHERE 
  # only include hits on pages
  hits.type = "PAGE"
  AND (SELECT MAX(IF(index=10, value, NULL)) FROM UNNEST(hits.customDimensions)) = \"{}\"
LIMIT 1""".format(recommended_content_ids[0])
current_title_sql="""
#standardSQL
SELECT
(SELECT MAX(IF(index=6, value, NULL)) FROM UNNEST(hits.customDimensions)) AS title
FROM `cloud-training-demos.GA360_test.ga_sessions_sample`,   
  UNNEST(hits) AS hits
WHERE 
  # only include hits on pages
  hits.type = "PAGE"
  AND (SELECT MAX(IF(index=10, value, NULL)) FROM UNNEST(hits.customDimensions)) = \"{}\"
LIMIT 1""".format(content_ids[0])
recommended_title = bq.Query(recommended_title_sql).execute().result().to_dataframe()['title'].tolist()[0]
current_title = bq.Query(current_title_sql).execute().result().to_dataframe()['title'].tolist()[0]
print("Current title: {} ".format(current_title))
print("Recommended title: {}".format(recommended_title))
# Out:
# Current title: Ehemalige Obdachlose: "Für mich war die Gruft eine Familie"
# Recommended title: Blümel, Kneissl &Co.: Das sind die Fixstarter

# %% [markdown]
# ### Tensorboard
#
# As usual, we can monitor the performance of our training job using Tensorboard.

# %%
from google.datalab.ml import TensorBoard
TensorBoard().start('./content_based_model_trained')

# %%
for pid in TensorBoard.list()['pid']:
  TensorBoard().stop(pid)
  print("Stopped TensorBoard with pid {}".format(pid))
